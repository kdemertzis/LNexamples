# %% [markdown]
# <a href="https://colab.research.google.com/github/kdemertzis/LNexamples/blob/main/Lazy_Predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install lazypredict
# Out:
# ...
#      |████████████████████████████████| 248 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 10.1 MB 19.5 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 43.3 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 19.2 MB/s
# ...
#      |████████████████████████████████| 302 kB 53.6 MB/s
# ...
#      |████████████████████████████████| 127.6 MB 23 kB/s
# ...
#      |████████████████████████████████| 14.5 MB 17.4 MB/s
# ...
#      |████████████████████████████████| 25.9 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 72 kB 849 kB/s
# ...
#      |████████████████████████████████| 269 kB 44.3 MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44635 sha256=99ef2f45ec8814c689366ff1425ff8c24e54b2fbb430578f24095934a7184fd9
#   Stored in directory: /root/.cache/pip/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
# Successfully built PyYAML
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
# ...

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
url = 'https://raw.githubusercontent.com/kdemertzis/Earthquakes/main/parkAng_total_89.csv'
# load the dataset
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    DI_PA_1st    PGA    PGV    PGD    I_A  ...     I_c  I_FVF   I_RG   SI_H  DI_PA
# 0       0.00 560.36 103.58 304.06 308.18  ... 5474.16 160.78 546.47 235.51   0.82
# 1       0.00 153.80  38.04  36.26 129.20  ... 1795.62  93.72 120.66 104.47   0.65
# 2       0.00 272.60  29.15   6.51 163.81  ... 2610.26  59.03  16.68 133.96   0.19
# 3       0.00 463.03  19.76   2.23 195.18  ... 3764.95  31.69   4.19  44.44   0.06
# 4       0.00  63.35   2.80   3.62   1.05  ...   72.96   4.58   6.98   4.47   0.03
#
# [5 rows x 18 columns]

# %%
Y_col = 'DI_PA'
X_cols = df.loc[:, df.columns != Y_col].columns

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[X_cols], df[Y_col],test_size=0.3, random_state=42)

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)

# %%
### fitting data in LazyClassifier
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
### lets check which model did better on Breast Cancer Dataset
print(models)
# Out:
# 100%|██████████| 42/42 [00:08<00:00,  4.81it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                                0.95       0.95  0.07        0.27
# RandomForestRegressor                        0.95       0.95  0.07        1.45
# HistGradientBoostingRegressor                0.95       0.95  0.07        0.95
# XGBRegressor                                 0.94       0.95  0.07        0.44
# ExtraTreesRegressor                          0.94       0.94  0.07        0.67
# GradientBoostingRegressor                    0.94       0.94  0.07        0.60
# BaggingRegressor                             0.94       0.94  0.07        0.19
# NuSVR                                        0.92       0.92  0.08        0.56
# MLPRegressor                                 0.92       0.92  0.08        0.40
# ExtraTreeRegressor                           0.91       0.91  0.09        0.03
# ...
