# %% [markdown]
# <a href="https://colab.research.google.com/github/kdemertzis/LNexamples/blob/main/Regr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('/content/insurance.csv')
print(df.head())
# Out:
#    age   sex    bmi  smoker    charges
# 0   18  male  23.21       0  1121.8739
# 1   18  male  30.14       0  1131.5066
# 2   18  male  33.33       0  1135.9407
# 3   18  male  33.66       0  1136.3994
# 4   18  male  34.10       0  1137.0110

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   age      1338 non-null   int64
#  1   sex      1338 non-null   object
#  2   bmi      1338 non-null   float64
#  3   smoker   1338 non-null   int64
#  4   charges  1338 non-null   float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 52.4+ KB
# None

# %%
print(df.corr())
# Out:
#               age       bmi    smoker   charges
# age      1.000000  0.109272 -0.025019  0.299008
# bmi      0.109272  1.000000  0.003750  0.198341
# smoker  -0.025019  0.003750  1.000000  0.787251
# charges  0.299008  0.198341  0.787251  1.000000

# %%
# Creating a pairwise plot in Seaborn
sns.pairplot(df, hue='smoker')
plt.show()

# %%
# Instantiating a LinearRegression Model
model = LinearRegression()

# %%
# Creating two arrays for the feature and target
X = non_smokers[['age']]
y = non_smokers['charges']

# %%
# Checking the type of our arrays
print('The type of X is ', type(X))
print('The type of y is ', type(y))
# Out:
# The type of X is  <class 'pandas.core.frame.DataFrame'>
# The type of y is  <class 'pandas.core.series.Series'>

# %%
# Fitting our model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Running Evaluation Metrics
predictions = model.predict(X_test)
r2 = r2_score(y_test, predictions)
rmse = mean_squared_error(y_test, predictions, squared=False)

print('The r2 is: ', r2)
print('The rmse is: ', rmse)
# Out:
# The r2 is:  0.7252533304194717
# The rmse is:  6329.170567313752

# %%
# Printing coefficients and intercept
print(model.coef_)
print(model.intercept_)
# Out:
# [  268.81265481   353.58093687 25309.34574727]
# -13296.50677363016

# %%
# Writing a function to predict charges
coefficients = model.coef_
intercept = model.intercept_
def calculate_charges(age, bmi, smoker):
  return (age * coefficients[0]) + (bmi * coefficients[1]) + (smoker * coefficients[2]) + intercept

# %%
# Predicting charges
print(calculate_charges(44, 42, 0))
# Out:
# 13381.649386225352
