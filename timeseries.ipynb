# %% [markdown]
# <a href="https://colab.research.google.com/github/kdemertzis/LNexamples/blob/main/timeseries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import STL

# Generate some example data
np.random.seed(0)
dates = pd.date_range(start='2022-01-01', end='2022-12-31')
data = np.random.randn(len(dates)).cumsum()
series = pd.Series(data, index=dates)

# Perform the time series decomposition
decomp = STL(series, seasonal=13)
result = decomp.fit()

# Extract the components
seasonal = result.seasonal
trend = result.trend
residuals = result.resid

# Plot the original series, components, and noise
plt.figure(figsize=(12, 6))
plt.subplot(4, 1, 1)
plt.plot(series)
plt.title('Original Series')
plt.subplot(4, 1, 2)
plt.plot(seasonal)
plt.title('Seasonal Component')
plt.subplot(4, 1, 3)
plt.plot(trend)
plt.title('Trend Component')
plt.subplot(4, 1, 4)
plt.plot(residuals)
plt.title('Noise (Residuals)')
plt.tight_layout()
plt.show()
