# %% [markdown]
# <a href="https://colab.research.google.com/github/kdemertzis/LNexamples/blob/main/TS_Decomposition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

# Step 1: Data Collection (Synthetic Data Generation)
np.random.seed(0)
dates = pd.date_range(start='2023-01-01', periods=365, freq='D')
values = np.random.randn(365).cumsum() + 100
data = pd.DataFrame({'Value': values}, index=dates)

# Step 2: Data Visualization
plt.plot(data.index, data['Value'])
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Data')
plt.show()

# Step 3: Data Preprocessing (not required for synthetic data)

# Step 4: Decomposition
decomposition = seasonal_decompose(data['Value'], model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Step 5: Statistical Analysis
# Augmented Dickey-Fuller test for stationarity
adf_result = adfuller(data['Value'])
print('ADF Statistic:', adf_result[0])
print('p-value:', adf_result[1])
print('Critical Values:', adf_result[4])

# Step 6: Model Selection (assume the data is stationary)
# Fit an ARIMA model
model = ARIMA(data['Value'], order=(1, 0, 1))
model_fit = model.fit()

# Step 7: Model Fitting (not required for synthetic data)

# Step 8: Model Evaluation
# Forecast the future values
forecast = model_fit.predict(start=len(data), end=len(data) + 10)

# Step 9: Forecasting
# Generate the forecast dates with the correct frequency
forecast_dates = pd.date_range(start=data.index[-1], periods=11, freq='D')

# Plot the forecasted values
plt.plot(data.index, data['Value'], label='Original Data')
plt.plot(forecast_dates, forecast, label='Forecast')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Forecast')
plt.legend()
plt.show()

# Step 10: Sensitivity Analysis (not included in this example)

# Step 11: Interpretation and Communication
print('Forecasted Values:')
print(forecast.values)
# Out:
# ADF Statistic: -0.9200020663522949
# p-value: 0.7813141076934433
# Critical Values: {'1%': -3.4484434475193777, '5%': -2.869513170510808, '10%': -2.571017574266393}
# Forecasted Values:
# [95.51889813 95.59184657 95.66419725 95.73595506 95.80712487 95.87771149
#  95.9477197  96.01715423 96.0860198  96.15432106 96.22206264]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

# Step 1: Data Collection (Synthetic Data Generation)
np.random.seed(0)
dates = pd.date_range(start='2023-01-01', periods=365, freq='D')
values = np.random.randn(365).cumsum() + 100
data = pd.DataFrame({'Value': values}, index=dates)

# Step 2: Data Visualization
plt.plot(data.index, data['Value'])
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Data')
plt.show()

# Step 3: Data Preprocessing (not required for synthetic data)

# Step 4: Decomposition
decomposition = seasonal_decompose(data['Value'], model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Visualize the decomposition components
plt.figure(figsize=(12, 8))

plt.subplot(411)
plt.plot(data.index, data['Value'], label='Original Data')
plt.legend()
plt.ylabel('Value')

plt.subplot(412)
plt.plot(data.index, trend, label='Trend')
plt.legend()
plt.ylabel('Trend')

plt.subplot(413)
plt.plot(data.index, seasonal, label='Seasonal')
plt.legend()
plt.ylabel('Seasonal')

plt.subplot(414)
plt.plot(data.index, residual, label='Residual')
plt.legend()
plt.ylabel('Residual')

plt.xlabel('Date')
plt.suptitle('Time Series Decomposition')
plt.show()

# Step 5: Statistical Analysis
# Augmented Dickey-Fuller test for stationarity
adf_result = adfuller(data['Value'])
print('ADF Statistic:', adf_result[0])
print('p-value:', adf_result[1])
print('Critical Values:', adf_result[4])

# Step 6: Model Selection (assume the data is stationary)
# Fit an ARIMA model
model = ARIMA(data['Value'], order=(1, 0, 1))
model_fit = model.fit()

# Step 7: Model Fitting (not required for synthetic data)

# Step 8: Model Evaluation
# Forecast the future values
forecast = model_fit.predict(start=len(data), end=len(data) + 10)

# Step 9: Forecasting
# Generate the forecast dates with the correct frequency
forecast_dates = pd.date_range(start=data.index[-1], periods=11, freq='D')

# Plot the forecasted values
plt.figure(figsize=(8, 6))
plt.plot(data.index, data['Value'], label='Original Data')
plt.plot(forecast_dates, forecast, label='Forecast')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Forecast')
plt.legend()
plt.show()

# Step 10: Sensitivity Analysis (not included in this example)

# Step 11: Interpretation and Communication
print('Forecasted Values:')
print(forecast.values)
# Out:
# ADF Statistic: -0.9200020663522949
# p-value: 0.7813141076934433
# Critical Values: {'1%': -3.4484434475193777, '5%': -2.869513170510808, '10%': -2.571017574266393}
# Forecasted Values:
# [95.51889813 95.59184657 95.66419725 95.73595506 95.80712487 95.87771149
#  95.9477197  96.01715423 96.0860198  96.15432106 96.22206264]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

# Step 1: Data Collection
data = pd.read_csv('https://raw.githubusercontent.com/kdemertzis/datashare/main/gold_daily.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# Step 2: Data Visualization
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Gold Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Daily Price')
plt.legend()
plt.show()

# Step 3: Data Preprocessing (not required for this example)

# Step 4: Decomposition
data.index = pd.to_datetime(data.index)  # Convert index to DatetimeIndex
data = data.asfreq('D')  # Set frequency to daily
data['Close'] = data['Close'].interpolate()  # Interpolate missing values
decomposition = seasonal_decompose(data['Close'], model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Visualize the decomposition components
plt.figure(figsize=(12, 8))

plt.subplot(411)
plt.plot(data.index, data['Close'], label='Original Data')
plt.legend()
plt.ylabel('Price')

plt.subplot(412)
plt.plot(data.index, trend, label='Trend')
plt.legend()
plt.ylabel('Trend')

plt.subplot(413)
plt.plot(data.index, seasonal, label='Seasonal')
plt.legend()
plt.ylabel('Seasonal')

plt.subplot(414)
plt.plot(data.index, residual, label='Residual')
plt.legend()
plt.ylabel('Residual')

plt.xlabel('Date')
plt.suptitle('Time Series Decomposition')
plt.show()

# Step 5: Statistical Analysis
# Augmented Dickey-Fuller test for stationarity
adf_result = adfuller(data['Close'])
print('ADF Statistic:', adf_result[0])
print('p-value:', adf_result[1])
print('Critical Values:')
for key, value in adf_result[4].items():
    print(f'{key}: {value}')

# Step 6: Model Selection (assume the data is stationary)
# Fit an ARIMA model
model = ARIMA(data['Close'], order=(1, 0, 1))
model_fit = model.fit()

# Step 7: Model Fitting (not required for this example)

# Step 8: Model Evaluation
# Forecast the future values
forecast = model_fit.predict(start=len(data), end=len(data) + 10)

# Step 9: Forecasting
# Generate the forecast dates
forecast_dates = pd.date_range(start=data.index[-1], periods=11, freq='D')

# Plot the forecasted values
plt.figure(figsize=(8, 6))
plt.plot(data.index, data['Close'], label='Original Data')
plt.plot(forecast_dates, forecast, label='Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Price Forecast')
plt.legend()
plt.show()

# Step 10: Sensitivity Analysis (not included in this example)

# Step 10: Sensitivity Analysis (not included in this example)

# Step 11: Interpretation and Communication
print('Forecasted Prices:')
print(forecast.values)

# Convert forecast and original data to a DataFrame for easier manipulation
forecast_df = pd.DataFrame(forecast, index=forecast_dates, columns=['Forecasted Price'])
original_df = pd.DataFrame(data['Close'])

# Combine original data and forecasted data into a single DataFrame
combined_df = original_df.append(forecast_df)

# Plot the original data and forecasted data
plt.figure(figsize=(10, 6))
plt.plot(combined_df.index, combined_df['Close'], label='Original Data')
plt.plot(forecast_df.index, forecast_df['Forecasted Price'], label='Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Price Forecast')
plt.legend()
plt.show()

# Step 12: Sensitivity Analysis (not included in this example)
# Out:
# ADF Statistic: -0.9476262419011984
# p-value: 0.7718842885489048
# Critical Values:
# 1%: -3.43114173721558
# 5%: -2.8618898926474574
# 10%: -2.566956243039254
# Forecasted Prices:
# [1723.35525074 1723.2095151  1723.06381048 1722.91813689 1722.77249431
#  1722.62688275 1722.48130218 1722.3357526  1722.19023402 1722.04474642
#  1721.89928979]
# <ipython-input-17-a7b25bc6283e>:107: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = original_df.append(forecast_df)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

# Step 1: Data Collection
data = pd.read_csv('https://raw.githubusercontent.com/kdemertzis/datashare/main/gold_daily.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# Step 2: Data Visualization
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Gold Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Daily Price')
plt.legend()
plt.show()

# Step 3: Data Preprocessing
data.index = pd.to_datetime(data.index)  # Convert index to DatetimeIndex
data = data.asfreq('D')  # Set frequency to daily
data['Close'] = data['Close'].interpolate()  # Interpolate missing values

# Step 4: Decomposition
decomposition = seasonal_decompose(data['Close'], model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Visualize the decomposition components
plt.figure(figsize=(12, 8))
plt.subplot(411)
plt.plot(data.index, data['Close'], label='Original Data')
plt.legend()
plt.ylabel('Price')
plt.subplot(412)
plt.plot(data.index, trend, label='Trend')
plt.legend()
plt.ylabel('Trend')
plt.subplot(413)
plt.plot(data.index, seasonal, label='Seasonal')
plt.legend()
plt.ylabel('Seasonal')
plt.subplot(414)
plt.plot(data.index, residual, label='Residual')
plt.legend()
plt.ylabel('Residual')
plt.xlabel('Date')
plt.suptitle('Time Series Decomposition')
plt.show()

# Step 5: Statistical Analysis
# Augmented Dickey-Fuller test for stationarity
adf_result = adfuller(data['Close'])
print('ADF Statistic:', adf_result[0])
print('p-value:', adf_result[1])
print('Critical Values:')
for key, value in adf_result[4].items():
    print(f'{key}: {value}')

# Step 6: Model Selection (assume the data is stationary)
# Fit an ARIMA model
model = ARIMA(data['Close'], order=(1, 0, 1))
model_fit = model.fit()

# Step 7: Model Fitting
# Optional: Fit the model to the entire data (not required for forecasting)
model_fit_full = model.fit()

# Step 8: Model Evaluation
# Forecast the future values
forecast_horizon = 45  # 45 days forecasting horizon
forecast = model_fit.predict(start=len(data), end=len(data) + forecast_horizon)

# Step 9: Forecasting
# Generate the forecast dates
forecast_dates = pd.date_range(start=data.index[-1], periods=forecast_horizon + 1, freq='D')

# Plot the original data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Original Data')
plt.plot(forecast_dates, forecast, label='Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Price Forecast')
plt.legend()
plt.show()

# Step 10: Sensitivity Analysis
# Optional: Perform sensitivity analysis or additional model evaluations

# Step 11: Interpretation and Communication
print('Forecasted Prices:')
print(forecast.values)

# Convert forecast and original data to a DataFrame for easier manipulation
forecast_df = pd.DataFrame(forecast, index=forecast_dates, columns=['Forecasted Price'])
original_df = pd.DataFrame(data['Close'])

# Combine original data and forecasted data into a single DataFrame
combined_df = original_df.append(forecast_df)

# Plot the original data and forecasted data
plt.figure(figsize=(10, 6))
plt.plot(combined_df.index, combined_df['Close'], label='Original Data')
plt.plot(forecast_df.index, forecast_df['Forecasted Price'], label='Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Price Forecast')
plt.legend()
plt.show()

# Step 12: Sensitivity Analysis (optional)
# Perform sensitivity analysis or additional steps

# Example: Evaluate the model performance on a test set (last 30 days)
test_data = data[-30:]
forecast_test = model_fit_full.predict(start=len(data), end=len(data) + len(test_data)-1)

# Calculate the mean absolute percentage error (MAPE)
mape = np.mean(np.abs((test_data['Close'] - forecast_test) / test_data['Close'])) * 100
print('Mean Absolute Percentage Error (MAPE):', mape)

# Plot the test data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(test_data.index, test_data['Close'], label='Test Data')
plt.plot(test_data.index, forecast_test, label='Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Model Performance on Test Data')
plt.legend()
plt.show()
# Out:
# ADF Statistic: -0.9476262419011984
# p-value: 0.7718842885489048
# Critical Values:
# 1%: -3.43114173721558
# 5%: -2.8618898926474574
# 10%: -2.566956243039254
# Forecasted Prices:
# [1723.35525074 1723.2095151  1723.06381048 1722.91813689 1722.77249431
#  1722.62688275 1722.48130218 1722.3357526  1722.19023402 1722.04474642
#  1721.89928979 1721.75386413 1721.60846943 1721.46310569 1721.31777289
#  1721.17247104 1721.02720013 1720.88196014 1720.73675108 1720.59157293
#  1720.44642569 1720.30130935 1720.15622391 1720.01116936 1719.86614569
#  1719.7211529  1719.57619097 1719.43125991 1719.28635971 1719.14149036
#  1718.99665185 1718.85184418 1718.70706733 1718.56232132 1718.41760611
#  1718.27292172 1718.12826814 1717.98364535 1717.83905335 1717.69449214
#  1717.5499617  1717.40546204 1717.26099314 1717.116555   1716.97214761
#  1716.82777096]
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

# Step 1: Data Collection
data = pd.read_csv('https://raw.githubusercontent.com/kdemertzis/datashare/main/gold_2020.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# Step 2: Data Visualization
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Gold Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Daily Price')
plt.legend()
plt.show()

# Step 3: Data Preprocessing
data.index = pd.to_datetime(data.index)  # Convert index to DatetimeIndex
data = data.asfreq('D')  # Set frequency to daily
data['Close'] = data['Close'].interpolate()  # Interpolate missing values

# Step 4: Decomposition
decomposition = seasonal_decompose(data['Close'], model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Visualize the decomposition components
plt.figure(figsize=(12, 8))
plt.subplot(411)
plt.plot(data.index, data['Close'], label='Original Data')
plt.legend()
plt.ylabel('Price')
plt.subplot(412)
plt.plot(data.index, trend, label='Trend')
plt.legend()
plt.ylabel('Trend')
plt.subplot(413)
plt.plot(data.index, seasonal, label='Seasonal')
plt.legend()
plt.ylabel('Seasonal')
plt.subplot(414)
plt.plot(data.index, residual, label='Residual')
plt.legend()
plt.ylabel('Residual')
plt.xlabel('Date')
plt.suptitle('Time Series Decomposition')
plt.show()

# Step 5: Statistical Analysis
# Augmented Dickey-Fuller test for stationarity
adf_result = adfuller(data['Close'])
print('ADF Statistic:', adf_result[0])
print('p-value:', adf_result[1])
print('Critical Values:')
for key, value in adf_result[4].items():
    print(f'{key}: {value}')

# Step 6: Model Selection (assume the data is stationary)
# Fit an ARIMA model
model = ARIMA(data['Close'], order=(1, 0, 1))
model_fit = model.fit()

# Step 7: Model Fitting
# Optional: Fit the model to the entire data (not required for forecasting)
model_fit_full = model.fit()

# Step 8: Model Evaluation
# Forecast the future values
forecast_horizon = 45  # 45 days forecasting horizon
forecast = model_fit.predict(start=len(data), end=len(data) + forecast_horizon)

# Step 9: Forecasting
# Generate the forecast dates
forecast_dates = pd.date_range(start=data.index[-1], periods=forecast_horizon + 1, freq='D')

# Plot the original data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Original Data')
plt.plot(forecast_dates, forecast, label='Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Price Forecast')
plt.legend()
plt.show()

# Step 10: Sensitivity Analysis
# Optional: Perform sensitivity analysis or additional model evaluations

# Step 11: Interpretation and Communication
print('Forecasted Prices:')
print(forecast.values)

# Convert forecast and original data to a DataFrame for easier manipulation
forecast_df = pd.DataFrame(forecast, index=forecast_dates, columns=['Forecasted Price'])
original_df = pd.DataFrame(data['Close'])

# Combine original data and forecasted data into a single DataFrame
combined_df = original_df.append(forecast_df)

# Plot the original data and forecasted data
plt.figure(figsize=(10, 6))
plt.plot(combined_df.index, combined_df['Close'], label='Original Data')
plt.plot(forecast_df.index, forecast_df['Forecasted Price'], label='Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Price Forecast')
plt.legend()
plt.show()

# Step 12: Sensitivity Analysis (optional)
# Perform sensitivity analysis or additional steps

# Example: Evaluate the model performance on a test set (last 30 days)
test_data = data[-30:]
forecast_test = model_fit_full.predict(start=len(data), end=len(data) + len(test_data)-1)

# Calculate the mean absolute percentage error (MAPE)
mape = np.mean(np.abs((test_data['Close'] - forecast_test) / test_data['Close'])) * 100
print('Mean Absolute Percentage Error (MAPE):', mape)

# Plot the test data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(test_data.index, test_data['Close'], label='Test Data')
plt.plot(test_data.index, forecast_test, label='Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Model Performance on Test Data')
plt.legend()
plt.show()
# Out:
# ADF Statistic: -2.813569294889016
# p-value: 0.0563614803571476
# Critical Values:
# 1%: -3.437137538234527
# 5%: -2.8645366106945414
# 10%: -2.568365556798649
# Forecasted Prices:
# [1723.99805369 1724.70286936 1725.40140891 1726.09372823 1726.77988271
#  1727.45992725 1728.13391625 1728.80190363 1729.46394285 1730.12008685
#  1730.77038814 1731.41489874 1732.05367023 1732.68675369 1733.31419979
#  1733.93605872 1734.55238023 1735.16321364 1735.7686078  1736.36861116
#  1736.96327172 1737.55263705 1738.13675431 1738.71567023 1739.28943112
#  1739.85808288 1740.42167102 1740.98024063 1741.53383638 1742.08250257
#  1742.6262831  1743.16522147 1743.6993608  1744.22874382 1744.75341288
#  1745.27340997 1745.78877668 1746.29955425 1746.80578354 1747.30750505
#  1747.80475892 1748.29758493 1748.78602251 1749.27011074 1749.74988836
#  1750.22539373]
# ...

# %%
! pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from pmdarima.arima import auto_arima

# Step 1: Data Collection
data = pd.read_csv('https://raw.githubusercontent.com/kdemertzis/datashare/main/gold_daily.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# Step 2: Data Visualization
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Gold Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Daily Price')
plt.legend()
plt.show()

# Step 3: Data Preprocessing
data.index = pd.to_datetime(data.index)  # Convert index to DatetimeIndex
data = data.asfreq('D')  # Set frequency to daily
data['Close'] = data['Close'].interpolate()  # Interpolate missing values

# Step 4: Decomposition
decomposition = seasonal_decompose(data['Close'], model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Visualize the decomposition components
plt.figure(figsize=(12, 8))
plt.subplot(411)
plt.plot(data.index, data['Close'], label='Original Data')
plt.legend()
plt.ylabel('Price')
plt.subplot(412)
plt.plot(data.index, trend, label='Trend')
plt.legend()
plt.ylabel('Trend')
plt.subplot(413)
plt.plot(data.index, seasonal, label='Seasonal')
plt.legend()
plt.ylabel('Seasonal')
plt.subplot(414)
plt.plot(data.index, residual, label='Residual')
plt.legend()
plt.ylabel('Residual')
plt.xlabel('Date')
plt.suptitle('Time Series Decomposition')
plt.show()

# Step 5: Statistical Analysis
# Augmented Dickey-Fuller test for stationarity
adf_result = adfuller(data['Close'])
print('ADF Statistic:', adf_result[0])
print('p-value:', adf_result[1])
print('Critical Values:')
for key, value in adf_result[4].items():
    print(f'{key}: {value}')

# Step 6: Model Selection (assume the data is stationary)
# Use auto_arima to determine the optimal ARIMA model parameters
model = auto_arima(data['Close'], seasonal=False, trace=True)

# Step 7: Model Fitting
# Optional: Fit the model to the entire data (not required for forecasting)
model_fit_full = model.fit(data['Close'])

# Step 8: Model Evaluation
# Forecast the future values
forecast_horizon = 45  # 45 days forecasting horizon
forecast, conf_int = model.predict(n_periods=forecast_horizon, return_conf_int=True)

# Step 9: Forecasting
# Generate the forecast dates
forecast_dates = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=forecast_horizon, freq='D')

# Plot the original data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Original Data')
plt.plot(forecast_dates, forecast, label='Forecast')
plt.fill_between(forecast_dates, conf_int[:, 0], conf_int[:, 1], alpha=0.2, label='Confidence Interval')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Price Forecast')
plt.legend()
plt.show()

# Step 10: Sensitivity Analysis (optional)
# Perform sensitivity analysis or additional steps

# Example: Evaluate the model performance on a test set (last 30 days)
test_data = data[-30:]
forecast_test, conf_int_test = model.predict(n_periods=len(test_data), return_conf_int=True)

# Calculate the mean absolute percentage error (MAPE)
mape = np.mean(np.abs((test_data['Close'].values - forecast_test) / test_data['Close'].values)) * 100
print('Mean Absolute Percentage Error (MAPE):', mape)

# Plot the test data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(test_data.index, test_data['Close'], label='Test Data')
plt.plot(test_data.index, forecast_test, label='Forecast')
plt.fill_between(test_data.index, conf_int_test[:, 0], conf_int_test[:, 1], alpha=0.2, label='Confidence Interval')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Model Performance on Test Data')
plt.legend()
plt.show()



# Step 11: Interpretation and Communication
print('Forecasted Prices:')
print(forecast.values)

# Convert forecast and original data to a DataFrame for easier manipulation
forecast_df = pd.DataFrame(forecast, index=forecast_dates, columns=['Forecasted Price'])
original_df = pd.DataFrame(data['Close'])

# Combine original data and forecasted data into a single DataFrame
combined_df = original_df.append(forecast_df)

# Plot the original data and forecasted data
plt.figure(figsize=(10, 6))
plt.plot(combined_df.index, combined_df['Close'], label='Original Data')
plt.plot(forecast_df.index, forecast_df['Forecasted Price'], label='Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Price Forecast')
plt.legend()
plt.show()

# Step 12: Sensitivity Analysis (optional)
# Perform sensitivity analysis or additional steps

# Example: Evaluate the model performance on a test set (last 30 days)
test_data = data[-30:]
forecast_test = model_fit_full.predict(start=len(data), end=len(data) + len(test_data)-1)

# Calculate the mean absolute percentage error (MAPE)
mape = np.mean(np.abs((test_data['Close'] - forecast_test) / test_data['Close'])) * 100
print('Mean Absolute Percentage Error (MAPE):', mape)
# Out:
# ADF Statistic: -0.9476262419011984
# p-value: 0.7718842885489048
# Critical Values:
# 1%: -3.43114173721558
# 5%: -2.8618898926474574
# 10%: -2.566956243039254
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=61191.222, Time=8.70 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=61213.561, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=61204.749, Time=0.24 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=61205.320, Time=0.53 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=61214.186, Time=0.18 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=61201.825, Time=3.41 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=61201.921, Time=2.67 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=61205.274, Time=3.09 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=61205.085, Time=7.16 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=61201.501, Time=1.67 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=61203.101, Time=2.85 sec
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from pmdarima.arima import auto_arima

# Step 1: Data Collection
data = pd.read_csv('https://raw.githubusercontent.com/kdemertzis/datashare/main/gold_daily.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# Step 2: Data Visualization
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Gold Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Daily Price')
plt.legend()
plt.show()

# Step 3: Data Preprocessing
data.index = pd.to_datetime(data.index)  # Convert index to DatetimeIndex
data = data.asfreq('D')  # Set frequency to daily
data['Close'] = data['Close'].interpolate()  # Interpolate missing values

# Step 4: Decomposition
decomposition = seasonal_decompose(data['Close'], model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Visualize the decomposition components
plt.figure(figsize=(12, 8))
plt.subplot(411)
plt.plot(data.index, data['Close'], label='Original Data')
plt.legend()
plt.ylabel('Price')
plt.subplot(412)
plt.plot(data.index, trend, label='Trend')
plt.legend()
plt.ylabel('Trend')
plt.subplot(413)
plt.plot(data.index, seasonal, label='Seasonal')
plt.legend()
plt.ylabel('Seasonal')
plt.subplot(414)
plt.plot(data.index, residual, label='Residual')
plt.legend()
plt.ylabel('Residual')
plt.xlabel('Date')
plt.suptitle('Time Series Decomposition')
plt.show()

# Step 5: Statistical Analysis
# Augmented Dickey-Fuller test for stationarity
adf_result = adfuller(data['Close'])
print('ADF Statistic:', adf_result[0])
print('p-value:', adf_result[1])
print('Critical Values:')
for key, value in adf_result[4].items():
    print(f'{key}: {value}')

# Step 6: Model Selection (assume the data is stationary)
# Use auto_arima to determine the optimal ARIMA model parameters
model = auto_arima(data['Close'], seasonal=False, trace=True)

# Step 7: Model Fitting
# Optional: Fit the model to the entire data (not required for forecasting)
model.fit(data['Close'])

# Step 8: Model Evaluation
# Forecast the future values
forecast_horizon = 45  # 45 days forecasting horizon
forecast, conf_int = model.predict(n_periods=forecast_horizon, return_conf_int=True)

# Step 9: Forecasting
# Generate the forecast dates
forecast_dates = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=forecast_horizon, freq='D')

# Plot the original data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Original Data')
plt.plot(forecast_dates, forecast, label='Forecast')
plt.fill_between(forecast_dates, conf_int[:, 0], conf_int[:, 1], alpha=0.2, label='Confidence Interval')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Price Forecast')
plt.legend()
plt.show()

# Step 10: Sensitivity Analysis (optional)
# Perform sensitivity analysis or additional steps

# Example: Evaluate the model performance on a test set (last 30 days)
test_data = data[-30:]
forecast_test, conf_int_test = model.predict(n_periods=len(test_data), return_conf_int=True)

# Calculate the mean absolute percentage error (MAPE)
mape = np.mean(np.abs((test_data['Close'].values - forecast_test) / test_data['Close'].values)) * 100
print('Mean Absolute Percentage Error (MAPE):', mape)

# Plot the test data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(test_data.index, test_data['Close'], label='Test Data')
plt.plot(test_data.index, forecast_test, label='Forecast')
plt.fill_between(test_data.index, conf_int_test[:, 0], conf_int_test[:, 1], alpha=0.2, label='Confidence Interval')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Model Performance on Test Data')
plt.legend()
plt.show()

# Step 11: Interpretation and Communication
print('Forecasted Prices:')
print(forecast)

# Convert forecast and original data to a DataFrame for easier manipulation
forecast_df = pd.DataFrame(forecast, index=forecast_dates, columns=['Forecasted Price'])
original_df = pd.DataFrame(data['Close'])

# Combine original data and forecasted data into a single DataFrame
combined_df = original_df.append(forecast_df)

# Plot the original data and forecasted data
plt.figure(figsize=(10, 6))
plt.plot(combined_df.index, combined_df['Close'], label='Original Data')
plt.plot(forecast_df.index, forecast_df['Forecasted Price'], label='Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Price Forecast')
plt.legend()
plt.show()

# Step 12: Sensitivity Analysis (optional)
# Perform sensitivity analysis or additional steps

# Example: Evaluate the model performance on a test set (last 30 days)
test_data = data[-30:]
forecast_test = model.predict(start=len(data), end=len(data) + len(test_data)-1)

# Calculate the mean absolute percentage error (MAPE)
mape = np.mean(np.abs((test_data['Close'] - forecast_test) / test_data['Close'])) * 100
print('Mean Absolute Percentage Error (MAPE):', mape)

# Plot the test data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(test_data.index, test_data['Close'], label='Test Data')
plt.plot(test_data.index[:len(forecast_test)], forecast_test, label='Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Model Performance on Test Data')
plt.legend()
plt.show()
# Out:
# ADF Statistic: -0.9476262419011984
# p-value: 0.7718842885489048
# Critical Values:
# 1%: -3.43114173721558
# 5%: -2.8618898926474574
# 10%: -2.566956243039254
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=61191.222, Time=9.34 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=61213.561, Time=0.19 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=61204.749, Time=0.37 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=61205.320, Time=0.94 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=61214.186, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=61201.825, Time=2.69 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=61201.921, Time=2.72 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=61205.274, Time=3.08 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=61205.085, Time=7.27 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=61201.501, Time=1.69 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=61203.101, Time=2.82 sec
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from pmdarima.arima import auto_arima

# Step 1: Data Collection
data = pd.read_csv('https://raw.githubusercontent.com/kdemertzis/datashare/main/gold_2020.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# Step 2: Data Visualization
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Gold Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Daily Price')
plt.legend()
plt.show()

# Step 3: Data Preprocessing
data.index = pd.to_datetime(data.index)  # Convert index to DatetimeIndex
data = data.asfreq('D')  # Set frequency to daily
data['Close'] = data['Close'].interpolate()  # Interpolate missing values

# Step 4: Decomposition
decomposition = seasonal_decompose(data['Close'], model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Visualize the decomposition components
plt.figure(figsize=(12, 8))
plt.subplot(411)
plt.plot(data.index, data['Close'], label='Original Data')
plt.legend()
plt.ylabel('Price')
plt.subplot(412)
plt.plot(data.index, trend, label='Trend')
plt.legend()
plt.ylabel('Trend')
plt.subplot(413)
plt.plot(data.index, seasonal, label='Seasonal')
plt.legend()
plt.ylabel('Seasonal')
plt.subplot(414)
plt.plot(data.index, residual, label='Residual')
plt.legend()
plt.ylabel('Residual')
plt.xlabel('Date')
plt.suptitle('Time Series Decomposition')
plt.show()

# Step 5: Statistical Analysis
# Augmented Dickey-Fuller test for stationarity
adf_result = adfuller(data['Close'])
print('ADF Statistic:', adf_result[0])
print('p-value:', adf_result[1])
print('Critical Values:')
for key, value in adf_result[4].items():
    print(f'{key}: {value}')

# Step 6: Model Selection (assume the data is stationary)
# Use auto_arima to determine the optimal ARIMA model parameters
model = auto_arima(data['Close'], seasonal=False, trace=True)

# Step 7: Model Fitting
# Optional: Fit the model to the entire data (not required for forecasting)
model.fit(data['Close'])

# Step 8: Model Evaluation
# Forecast the future values
forecast_horizon = 125  # 125 days forecasting horizon
forecast, conf_int = model.predict(n_periods=forecast_horizon, return_conf_int=True)

# Step 9: Forecasting
# Generate the forecast dates
forecast_dates = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=forecast_horizon, freq='D')

# Plot the original data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Original Data')
plt.plot(forecast_dates, forecast, label='Forecast')
plt.fill_between(forecast_dates, conf_int[:, 0], conf_int[:, 1], alpha=0.2, label='Confidence Interval')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Price Forecast')
plt.legend()
plt.show()

# Step 10: Sensitivity Analysis (optional)
# Perform sensitivity analysis or additional steps

# Example: Evaluate the model performance on a test set (last 130 days)
test_data = data[-130:]
forecast_test, conf_int_test = model.predict(n_periods=len(test_data), return_conf_int=True)

# Calculate the mean absolute percentage error (MAPE)
mape = np.mean(np.abs((test_data['Close'].values - forecast_test) / test_data['Close'].values)) * 100
print('Mean Absolute Percentage Error (MAPE):', mape)

# Plot the test data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(test_data.index, test_data['Close'], label='Test Data')
plt.plot(test_data.index, forecast_test, label='Forecast')
plt.fill_between(test_data.index, conf_int_test[:, 0], conf_int_test[:, 1], alpha=0.2, label='Confidence Interval')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Model Performance on Test Data')
plt.legend()
plt.show()

# Step 11: Interpretation and Communication
print('Forecasted Prices:')
print(forecast)

# Convert forecast and original data to a DataFrame for easier manipulation
forecast_df = pd.DataFrame(forecast, index=forecast_dates, columns=['Forecasted Price'])
original_df = pd.DataFrame(data['Close'])

# Combine original data and forecasted data into a single DataFrame
combined_df = original_df.append(forecast_df)

# Plot the original data and forecasted data
plt.figure(figsize=(10, 6))
plt.plot(combined_df.index, combined_df['Close'], label='Original Data')
plt.plot(forecast_df.index, forecast_df['Forecasted Price'], label='Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Price Forecast')
plt.legend()
plt.show()

# Step 12: Sensitivity Analysis (optional)
# Perform sensitivity analysis or additional steps

# Example: Evaluate the model performance on a test set (last 130 days)
test_data = data[-130:]
forecast_test = model.predict(start=len(data), end=len(data) + len(test_data)-1)

# Calculate the mean absolute percentage error (MAPE)
mape = np.mean(np.abs((test_data['Close'] - forecast_test) / test_data['Close'])) * 100
print('Mean Absolute Percentage Error (MAPE):', mape)

# Plot the test data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(test_data.index, test_data['Close'], label='Test Data')
plt.plot(test_data.index[:len(forecast_test)], forecast_test, label='Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Model Performance on Test Data')
plt.legend()
plt.show()
# Out:
# ADF Statistic: -2.813569294889016
# p-value: 0.0563614803571476
# Critical Values:
# 1%: -3.437137538234527
# 5%: -2.8645366106945414
# 10%: -2.568365556798649
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=8071.361, Time=0.68 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=8070.394, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=8072.050, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=8072.087, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=8068.562, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=8073.187, Time=0.39 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.449 seconds
# Mean Absolute Percentage Error (MAPE): 4.491317313029864
# Forecasted Prices:
# 2022-09-03    1723.0
# 2022-09-04    1723.0
# 2022-09-05    1723.0
# 2022-09-06    1723.0
# 2022-09-07    1723.0
#                ...
# 2023-01-01    1723.0
# 2023-01-02    1723.0
# 2023-01-03    1723.0
# 2023-01-04    1723.0
# ...
