# %% [markdown]
# <a href="https://colab.research.google.com/github/kdemertzis/LNexamples/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install pycaret

# %%
import pycaret
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pycaret.classification import *

# %%
# define the location of the dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv'
# load the dataset
df = pd.read_csv(url, header=None)
# summarize the shape of the dataset
print(df.shape)
# Out:
# (208, 61)

# %%
# set column names as the column number
n_cols = df.shape[1]
df.columns = [str(i) for i in range(n_cols)]

# %%
# summarize the first few rows of data
print(df.head())
# Out:
#         0       1       2       3       4  ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117   R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
# setup the dataset
grid = setup(data=df, target=df.columns[-1], html=False, silent=True, verbose=False)

# %%
best = compare_models(cross_validation=False, n_select = 1) 
# %load_ext tensorboard
# Out:
#                   Model  Accuracy     AUC  Recall   Prec.      F1  Kappa  \
# lr  Logistic Regression     0.746  0.8347  0.7857  0.6875  0.7333  0.493
#
#       MCC  TT (Sec)
# lr  0.497      0.01
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# knn  K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600  0.7170  0.5126
# lr      Logistic Regression    0.7460  0.8347  0.7857  0.6875  0.7333  0.4930
#
#         MCC  TT (Sec)
# knn  0.5151      0.00
# lr   0.4970      0.01
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# knn  K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600  0.7170  0.5126
# lr      Logistic Regression    0.7460  0.8347  0.7857  0.6875  0.7333  0.4930
# nb              Naive Bayes    0.6349  0.8163  0.7857  0.5641  0.6567  0.2887
#
#         MCC  TT (Sec)
# knn  0.5151      0.00
# lr   0.4970      0.01
# nb   0.3070      0.01
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# knn    K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600  0.7170
# lr        Logistic Regression    0.7460  0.8347  0.7857  0.6875  0.7333
# dt   Decision Tree Classifier    0.7302  0.7214  0.6429  0.7200  0.6792
# nb                Naive Bayes    0.6349  0.8163  0.7857  0.5641  0.6567
#
#       Kappa     MCC  TT (Sec)
# knn  0.5126  0.5151      0.00
# lr   0.4930  0.4970      0.01
# dt   0.4477  0.4498      0.01
# nb   0.2887  0.3070      0.01
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# svm       SVM - Linear Kernel    0.7778  0.7536  0.5357  0.9375  0.6818
# knn    K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600  0.7170
# lr        Logistic Regression    0.7460  0.8347  0.7857  0.6875  0.7333
# dt   Decision Tree Classifier    0.7302  0.7214  0.6429  0.7200  0.6792
# nb                Naive Bayes    0.6349  0.8163  0.7857  0.5641  0.6567
#
#       Kappa     MCC  TT (Sec)
# svm  0.5299  0.5789      0.01
# knn  0.5126  0.5151      0.00
# lr   0.4930  0.4970      0.01
# dt   0.4477  0.4498      0.01
# nb   0.2887  0.3070      0.01
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# ridge          Ridge Classifier    0.7937  0.7893  0.7500  0.7778  0.7636
# svm         SVM - Linear Kernel    0.7778  0.7536  0.5357  0.9375  0.6818
# knn      K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600  0.7170
# lr          Logistic Regression    0.7460  0.8347  0.7857  0.6875  0.7333
# dt     Decision Tree Classifier    0.7302  0.7214  0.6429  0.7200  0.6792
# nb                  Naive Bayes    0.6349  0.8163  0.7857  0.5641  0.6567
#
#         Kappa     MCC  TT (Sec)
# ridge  0.5806  0.5809      0.01
# svm    0.5299  0.5789      0.01
# knn    0.5126  0.5151      0.00
# lr     0.4930  0.4970      0.01
# dt     0.4477  0.4498      0.01
# nb     0.2887  0.3070      0.01
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# rf     Random Forest Classifier    0.8413  0.8990  0.7500  0.8750  0.8077
# ridge          Ridge Classifier    0.7937  0.7893  0.7500  0.7778  0.7636
# svm         SVM - Linear Kernel    0.7778  0.7536  0.5357  0.9375  0.6818
# knn      K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600  0.7170
# lr          Logistic Regression    0.7460  0.8347  0.7857  0.6875  0.7333
# dt     Decision Tree Classifier    0.7302  0.7214  0.6429  0.7200  0.6792
# nb                  Naive Bayes    0.6349  0.8163  0.7857  0.5641  0.6567
#
#         Kappa     MCC  TT (Sec)
# rf     0.6739  0.6797      0.66
# ridge  0.5806  0.5809      0.01
# svm    0.5299  0.5789      0.01
# knn    0.5126  0.5151      0.00
# lr     0.4930  0.4970      0.01
# dt     0.4477  0.4498      0.01
# nb     0.2887  0.3070      0.01
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.8413  0.8990  0.7500  0.8750
# ridge                 Ridge Classifier    0.7937  0.7893  0.7500  0.7778
# svm                SVM - Linear Kernel    0.7778  0.7536  0.5357  0.9375
# knn             K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600
# lr                 Logistic Regression    0.7460  0.8347  0.7857  0.6875
# dt            Decision Tree Classifier    0.7302  0.7214  0.6429  0.7200
# qda    Quadratic Discriminant Analysis    0.6667  0.7393  0.3929  0.7333
# nb                         Naive Bayes    0.6349  0.8163  0.7857  0.5641
#
#            F1   Kappa     MCC  TT (Sec)
# rf     0.8077  0.6739  0.6797      0.66
# ridge  0.7636  0.5806  0.5809      0.01
# svm    0.6818  0.5299  0.5789      0.01
# knn    0.7170  0.5126  0.5151      0.00
# lr     0.7333  0.4930  0.4970      0.01
# dt     0.6792  0.4477  0.4498      0.01
# qda    0.5116  0.2921  0.3250      0.01
# nb     0.6567  0.2887  0.3070      0.01
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# ada               Ada Boost Classifier    0.8571  0.9102  0.8214  0.8519
# rf            Random Forest Classifier    0.8413  0.8990  0.7500  0.8750
# ridge                 Ridge Classifier    0.7937  0.7893  0.7500  0.7778
# svm                SVM - Linear Kernel    0.7778  0.7536  0.5357  0.9375
# knn             K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600
# lr                 Logistic Regression    0.7460  0.8347  0.7857  0.6875
# dt            Decision Tree Classifier    0.7302  0.7214  0.6429  0.7200
# qda    Quadratic Discriminant Analysis    0.6667  0.7393  0.3929  0.7333
# nb                         Naive Bayes    0.6349  0.8163  0.7857  0.5641
#
#            F1   Kappa     MCC  TT (Sec)
# ada    0.8364  0.7097  0.7100      0.12
# rf     0.8077  0.6739  0.6797      0.66
# ridge  0.7636  0.5806  0.5809      0.01
# svm    0.6818  0.5299  0.5789      0.01
# knn    0.7170  0.5126  0.5151      0.00
# lr     0.7333  0.4930  0.4970      0.01
# dt     0.6792  0.4477  0.4498      0.01
# qda    0.5116  0.2921  0.3250      0.01
# nb     0.6567  0.2887  0.3070      0.01
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# ada               Ada Boost Classifier    0.8571  0.9102  0.8214  0.8519
# gbc       Gradient Boosting Classifier    0.8571  0.9408  0.7500  0.9130
# rf            Random Forest Classifier    0.8413  0.8990  0.7500  0.8750
# ridge                 Ridge Classifier    0.7937  0.7893  0.7500  0.7778
# svm                SVM - Linear Kernel    0.7778  0.7536  0.5357  0.9375
# knn             K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600
# lr                 Logistic Regression    0.7460  0.8347  0.7857  0.6875
# dt            Decision Tree Classifier    0.7302  0.7214  0.6429  0.7200
# qda    Quadratic Discriminant Analysis    0.6667  0.7393  0.3929  0.7333
# nb                         Naive Bayes    0.6349  0.8163  0.7857  0.5641
#
#            F1   Kappa     MCC  TT (Sec)
# ada    0.8364  0.7097  0.7100      0.12
# gbc    0.8235  0.7055  0.7151      0.27
# rf     0.8077  0.6739  0.6797      0.66
# ridge  0.7636  0.5806  0.5809      0.01
# svm    0.6818  0.5299  0.5789      0.01
# knn    0.7170  0.5126  0.5151      0.00
# lr     0.7333  0.4930  0.4970      0.01
# dt     0.6792  0.4477  0.4498      0.01
# qda    0.5116  0.2921  0.3250      0.01
# nb     0.6567  0.2887  0.3070      0.01
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# ada               Ada Boost Classifier    0.8571  0.9102  0.8214  0.8519
# gbc       Gradient Boosting Classifier    0.8571  0.9408  0.7500  0.9130
# rf            Random Forest Classifier    0.8413  0.8990  0.7500  0.8750
# ridge                 Ridge Classifier    0.7937  0.7893  0.7500  0.7778
# svm                SVM - Linear Kernel    0.7778  0.7536  0.5357  0.9375
# knn             K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600
# lr                 Logistic Regression    0.7460  0.8347  0.7857  0.6875
# dt            Decision Tree Classifier    0.7302  0.7214  0.6429  0.7200
# lda       Linear Discriminant Analysis    0.7302  0.7592  0.6786  0.7037
# qda    Quadratic Discriminant Analysis    0.6667  0.7393  0.3929  0.7333
# nb                         Naive Bayes    0.6349  0.8163  0.7857  0.5641
#
#            F1   Kappa     MCC  TT (Sec)
# ada    0.8364  0.7097  0.7100      0.12
# gbc    0.8235  0.7055  0.7151      0.27
# rf     0.8077  0.6739  0.6797      0.66
# ridge  0.7636  0.5806  0.5809      0.01
# svm    0.6818  0.5299  0.5789      0.01
# knn    0.7170  0.5126  0.5151      0.00
# lr     0.7333  0.4930  0.4970      0.01
# dt     0.6792  0.4477  0.4498      0.01
# lda    0.6909  0.4516  0.4518      0.01
# qda    0.5116  0.2921  0.3250      0.01
# nb     0.6567  0.2887  0.3070      0.01
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# et              Extra Trees Classifier    0.8889  0.9653  0.8571  0.8889
# ada               Ada Boost Classifier    0.8571  0.9102  0.8214  0.8519
# gbc       Gradient Boosting Classifier    0.8571  0.9408  0.7500  0.9130
# rf            Random Forest Classifier    0.8413  0.8990  0.7500  0.8750
# ridge                 Ridge Classifier    0.7937  0.7893  0.7500  0.7778
# svm                SVM - Linear Kernel    0.7778  0.7536  0.5357  0.9375
# knn             K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600
# lr                 Logistic Regression    0.7460  0.8347  0.7857  0.6875
# dt            Decision Tree Classifier    0.7302  0.7214  0.6429  0.7200
# lda       Linear Discriminant Analysis    0.7302  0.7592  0.6786  0.7037
# qda    Quadratic Discriminant Analysis    0.6667  0.7393  0.3929  0.7333
# nb                         Naive Bayes    0.6349  0.8163  0.7857  0.5641
#
#            F1   Kappa     MCC  TT (Sec)
# et     0.8727  0.7742  0.7746      0.66
# ada    0.8364  0.7097  0.7100      0.12
# gbc    0.8235  0.7055  0.7151      0.27
# rf     0.8077  0.6739  0.6797      0.66
# ridge  0.7636  0.5806  0.5809      0.01
# svm    0.6818  0.5299  0.5789      0.01
# knn    0.7170  0.5126  0.5151      0.00
# lr     0.7333  0.4930  0.4970      0.01
# dt     0.6792  0.4477  0.4498      0.01
# lda    0.6909  0.4516  0.4518      0.01
# qda    0.5116  0.2921  0.3250      0.01
# nb     0.6567  0.2887  0.3070      0.01
#                                    Model  Accuracy     AUC  Recall   Prec.  \
# et                Extra Trees Classifier    0.8889  0.9653  0.8571  0.8889
# ada                 Ada Boost Classifier    0.8571  0.9102  0.8214  0.8519
# gbc         Gradient Boosting Classifier    0.8571  0.9408  0.7500  0.9130
# rf              Random Forest Classifier    0.8413  0.8990  0.7500  0.8750
# xgboost        Extreme Gradient Boosting    0.8413  0.9408  0.8214  0.8214
# ridge                   Ridge Classifier    0.7937  0.7893  0.7500  0.7778
# svm                  SVM - Linear Kernel    0.7778  0.7536  0.5357  0.9375
# knn               K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600
# lr                   Logistic Regression    0.7460  0.8347  0.7857  0.6875
# dt              Decision Tree Classifier    0.7302  0.7214  0.6429  0.7200
# lda         Linear Discriminant Analysis    0.7302  0.7592  0.6786  0.7037
# qda      Quadratic Discriminant Analysis    0.6667  0.7393  0.3929  0.7333
# nb                           Naive Bayes    0.6349  0.8163  0.7857  0.5641
#
#              F1   Kappa     MCC  TT (Sec)
# et       0.8727  0.7742  0.7746      0.66
# ada      0.8364  0.7097  0.7100      0.12
# gbc      0.8235  0.7055  0.7151      0.27
# rf       0.8077  0.6739  0.6797      0.66
# xgboost  0.8214  0.6786  0.6786      0.13
# ridge    0.7636  0.5806  0.5809      0.01
# svm      0.6818  0.5299  0.5789      0.01
# knn      0.7170  0.5126  0.5151      0.00
# lr       0.7333  0.4930  0.4970      0.01
# dt       0.6792  0.4477  0.4498      0.01
# lda      0.6909  0.4516  0.4518      0.01
# qda      0.5116  0.2921  0.3250      0.01
# nb       0.6567  0.2887  0.3070      0.01
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.8889  0.9653  0.8571  0.8889
# lightgbm  Light Gradient Boosting Machine    0.8730  0.9327  0.7857  0.9167
# ada                  Ada Boost Classifier    0.8571  0.9102  0.8214  0.8519
# gbc          Gradient Boosting Classifier    0.8571  0.9408  0.7500  0.9130
# rf               Random Forest Classifier    0.8413  0.8990  0.7500  0.8750
# xgboost         Extreme Gradient Boosting    0.8413  0.9408  0.8214  0.8214
# ridge                    Ridge Classifier    0.7937  0.7893  0.7500  0.7778
# svm                   SVM - Linear Kernel    0.7778  0.7536  0.5357  0.9375
# knn                K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600
# lr                    Logistic Regression    0.7460  0.8347  0.7857  0.6875
# dt               Decision Tree Classifier    0.7302  0.7214  0.6429  0.7200
# lda          Linear Discriminant Analysis    0.7302  0.7592  0.6786  0.7037
# qda       Quadratic Discriminant Analysis    0.6667  0.7393  0.3929  0.7333
# nb                            Naive Bayes    0.6349  0.8163  0.7857  0.5641
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.8727  0.7742  0.7746      0.66
# lightgbm  0.8462  0.7391  0.7455      0.04
# ada       0.8364  0.7097  0.7100      0.12
# gbc       0.8235  0.7055  0.7151      0.27
# rf        0.8077  0.6739  0.6797      0.66
# xgboost   0.8214  0.6786  0.6786      0.13
# ridge     0.7636  0.5806  0.5809      0.01
# svm       0.6818  0.5299  0.5789      0.01
# knn       0.7170  0.5126  0.5151      0.00
# lr        0.7333  0.4930  0.4970      0.01
# dt        0.6792  0.4477  0.4498      0.01
# lda       0.6909  0.4516  0.4518      0.01
# qda       0.5116  0.2921  0.3250      0.01
# nb        0.6567  0.2887  0.3070      0.01
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# catboost              CatBoost Classifier    0.9048  0.9367  0.8214  0.9583
# et                 Extra Trees Classifier    0.8889  0.9653  0.8571  0.8889
# lightgbm  Light Gradient Boosting Machine    0.8730  0.9327  0.7857  0.9167
# ada                  Ada Boost Classifier    0.8571  0.9102  0.8214  0.8519
# gbc          Gradient Boosting Classifier    0.8571  0.9408  0.7500  0.9130
# rf               Random Forest Classifier    0.8413  0.8990  0.7500  0.8750
# xgboost         Extreme Gradient Boosting    0.8413  0.9408  0.8214  0.8214
# ridge                    Ridge Classifier    0.7937  0.7893  0.7500  0.7778
# svm                   SVM - Linear Kernel    0.7778  0.7536  0.5357  0.9375
# knn                K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600
# lr                    Logistic Regression    0.7460  0.8347  0.7857  0.6875
# dt               Decision Tree Classifier    0.7302  0.7214  0.6429  0.7200
# lda          Linear Discriminant Analysis    0.7302  0.7592  0.6786  0.7037
# qda       Quadratic Discriminant Analysis    0.6667  0.7393  0.3929  0.7333
# nb                            Naive Bayes    0.6349  0.8163  0.7857  0.5641
#
#               F1   Kappa     MCC  TT (Sec)
# catboost  0.8846  0.8043  0.8113      9.49
# et        0.8727  0.7742  0.7746      0.66
# lightgbm  0.8462  0.7391  0.7455      0.04
# ada       0.8364  0.7097  0.7100      0.12
# gbc       0.8235  0.7055  0.7151      0.27
# rf        0.8077  0.6739  0.6797      0.66
# xgboost   0.8214  0.6786  0.6786      0.13
# ridge     0.7636  0.5806  0.5809      0.01
# svm       0.6818  0.5299  0.5789      0.01
# knn       0.7170  0.5126  0.5151      0.00
# lr        0.7333  0.4930  0.4970      0.01
# dt        0.6792  0.4477  0.4498      0.01
# lda       0.6909  0.4516  0.4518      0.01
# qda       0.5116  0.2921  0.3250      0.01
# nb        0.6567  0.2887  0.3070      0.01
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# catboost              CatBoost Classifier    0.9048  0.9367  0.8214  0.9583
# et                 Extra Trees Classifier    0.8889  0.9653  0.8571  0.8889
# lightgbm  Light Gradient Boosting Machine    0.8730  0.9327  0.7857  0.9167
# ada                  Ada Boost Classifier    0.8571  0.9102  0.8214  0.8519
# gbc          Gradient Boosting Classifier    0.8571  0.9408  0.7500  0.9130
# rf               Random Forest Classifier    0.8413  0.8990  0.7500  0.8750
# xgboost         Extreme Gradient Boosting    0.8413  0.9408  0.8214  0.8214
# ridge                    Ridge Classifier    0.7937  0.7893  0.7500  0.7778
# svm                   SVM - Linear Kernel    0.7778  0.7536  0.5357  0.9375
# knn                K Neighbors Classifier    0.7619  0.8102  0.6786  0.7600
# lr                    Logistic Regression    0.7460  0.8347  0.7857  0.6875
# dt               Decision Tree Classifier    0.7302  0.7214  0.6429  0.7200
# lda          Linear Discriminant Analysis    0.7302  0.7592  0.6786  0.7037
# qda       Quadratic Discriminant Analysis    0.6667  0.7393  0.3929  0.7333
# nb                            Naive Bayes    0.6349  0.8163  0.7857  0.5641
#
#               F1   Kappa     MCC  TT (Sec)
# catboost  0.8846  0.8043  0.8113      9.49
# et        0.8727  0.7742  0.7746      0.66
# lightgbm  0.8462  0.7391  0.7455      0.04
# ada       0.8364  0.7097  0.7100      0.12
# gbc       0.8235  0.7055  0.7151      0.27
# rf        0.8077  0.6739  0.6797      0.66
# xgboost   0.8214  0.6786  0.6786      0.13
# ridge     0.7636  0.5806  0.5809      0.01
# svm       0.6818  0.5299  0.5789      0.01
# knn       0.7170  0.5126  0.5151      0.00
# lr        0.7333  0.4930  0.4970      0.01
# dt        0.6792  0.4477  0.4498      0.01
# lda       0.6909  0.4516  0.4518      0.01
# qda       0.5116  0.2921  0.3250      0.01
# nb        0.6567  0.2887  0.3070      0.01
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# report the best model
print(best)
# Out:
# <catboost.core.CatBoostClassifier object at 0x7fc871689358>

# %%
plot_model(best, plot = 'feature')

# %%
plot_model(best, plot = 'confusion_matrix')

# %%
plot_model(best, plot = 'class_report')

# %%
plot_model(best, plot = 'auc')

# %%
plot_model(best, plot = 'error')
